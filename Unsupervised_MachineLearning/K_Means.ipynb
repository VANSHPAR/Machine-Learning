# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

data={
    'Customer':['abc','def','ghi','jkl','mno','pqr'],
    'Age':[20,30,40,28,38,35],
    'Spending':[100,200,300,110,290,250]
}
df=pd.DataFrame(data)

X=df[['Age','Spending']]

model=KMeans(n_clusters=2,random_state=42,n_init=10)
#n_clusters means no. groups that you want to divide data
#try clustering 10 times from  different starting points and peak best possible group

df['Group']=model.fit_predict(X)

plt.figure(figsize=(6,5))
for group in df['Group'].unique(): #.unique gives distinct values
    group_data=df[df['Group']==group]
    plt.scatter(group_data['Age'],group_data['Spending'],label=f'Group {group}')

plt.xlabel('Age')
plt.ylabel('Spending')
plt.title('Customer Segements (K-Means)')
plt.legend()
plt.grid(True)
plt.show()

print(df)
# Out:
#   Customer  Age  Spending  Group
# 0      abc   20       100      0
# 1      def   30       200      1
# 2      ghi   40       300      1
# 3      jkl   28       110      0
# 4      mno   38       290      1
# 5      pqr   35       250      1

# %%
#Principal Component Analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

data={
    'Age':[25,30,35,40,46,50],
    'Income':[30000,40000,50000,60000,70000,80000],
    'Spending':[70,60,50,40,30,21],
    'Savings':[1000,5000,8000,10000,18000,22000]
}
df=pd.DataFrame(data)

scaler=StandardScaler()
scaled_data=scaler.fit_transform(df)

pca=PCA(n_components=2)
#4 cols summarized into 2 cols
pca_result=pca.fit_transform(scaled_data)

pca_df=pd.DataFrame(pca_result,columns=['PCA1','PCA2'])

explained_variance=pca.explained_variance_ratio_
print('variance captured by each PCA component: ')
print(np.round(explained_variance*100,2))

plt.figure(figsize=(8,6))
plt.scatter(pca_df['PCA1'],pca_df['PCA2'],color='black',s=80)
plt.title('PCA Projection (2D View)')
plt.xlabel('PCA1 Main pattern')
plt.ylabel('PCA2 minor pattern')
plt.grid(True)
plt.show()

print('New data')
print(pca_df)


"""
in your resume there are
education
work exp
projects 
skills

this data sumarized into
pca1=carrenr readiness score 
pca2=special skillset score
"""
# Out:
# variance captured by each PCA component:
# [99.34  0.64]
# New data
#        PCA1      PCA2
# 0 -2.865126  0.104562
# 1 -1.711798  0.078938
# 2 -0.627006 -0.065904
# 3  0.389252 -0.329965
# 4  1.874383  0.096253
# 5  2.940295  0.116115
